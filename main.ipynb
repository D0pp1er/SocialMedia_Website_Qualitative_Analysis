# %%
import pandas as pd
df = pd.read_csv('Questioneer (Responses) - Response Backup.csv')

# %%
df.columns.values
# Out:
# array(['Timestamp', 'Name', 'Age', 'Gender',
#        'Living place(Home district)', 'Contact no(Optional)',
#        'Email(optional)', 'Education', 'Occupation',
#        'Electronic devices used by you', 'Do you use social media?',
#        'How many hours in a day do you use social media?',
#        'How frequently do you buy products online?',
#        'What are the advantages or disadvantages of shopping through social media?',
#        'Do you have any online portal of your shop? ',
#        "If you don't have a online portal of your shop, which will you create first?",
#        '"When I go to any website I look for social media handle." How much do you agree?',
#        'What is your impression about websites  not having social media handle and What is your impression about social media handles not having websites?',
#        'Over shopping in websites and shopping in social media which one you will pick? why?',
# ...

# %%
for idx,row in enumerate(df.values):
    with open(f'responses/{idx+20}.txt', 'w') as f:
        for idx,i,j in zip(range(1, len(df.columns)),df.columns, row):
            f.write(f'Q{idx}. {i} \nA. {j} \n\n')

# %%
names = '''Abrar
Ashraf
AronNo
Avi Dewan
Fahim
Hamza
Naimul Islam
Sultan Mahfuz
Imrul Hasan Hridoy
Ismail
Mahir Sadiq
Abu kayum sourov
Tanvir Mahmud
Nabil Sadique
Rahi
Sifwat alvi
Abdul Munaf
Akhil Kumar
Sheikh Sohel Ahmed
Ahad Kaiser Tamim
Fatin Ahmed
Firdous siddique
G.R.Solaiman Rafi
Golam Mahadi Ahmed
Jinan
Labiba Islam Salsabil
Masfik Hasan
Md. Julkar Nayeem
Md. sabbir ahmed
Mohaimininul Islam
Mohammod Mahbubur Rahman
Morsheda Akter
Mst. Tania Islam
Rumaysa Mumtahana
Sadia Afrin
Sarah
Shahrin Rahman
Shazid Abdullah
Tabassum Hasan
Tisum
Tanveer
Tarek Bari
Tasnim Zarin Semontee
Tonmoy
Zarin
Alina Hasan
Anushua Ahmed
Anjuman Ara Begum
Fahim Hossain
Md Babul Hossain
Md Sohel Hosen
Nafiul Islam
Md Sabbir Ahmed
Shahida Akter
Md Shafayatul Haq Tonmoy
Labiba Islam Salsabil 
Tabassum Hasan Tisum 
Rikta Parvin
Reazul Alavhi
Jarif Islam
Al-Amin Sany
Rakib Ahsan
Akanta Das
Nahida Marzan
Tansim Zarin
Ime
Israt Zarin Era
Tasfia Islam Prova
Tasnim
Farhana
Faria Halim Esha
Saba
Anika Afrin
Suraya Sultana
Annesha Bhowmik Arpa
Purbasha Halder
Zarin Tasnim Abid
Shaharin Sultana Showvi
Sadia Binte Islam
Nora
Nusrat Kotha
Jannatul Bushra Jarin
Shelina
Adrita Balo
Fariha Binte Reeha'''

names = names.split('\n')

# %%
t = [i.strip() for i in df['Name'].values]
for i in names:
    if i not in t:
        print(i)
# Out:
# Abrar
# Ashraf
# AronNo
# Avi Dewan
# Fahim
# Hamza
# Naimul Islam
# Sultan Mahfuz
# Imrul Hasan Hridoy
# Ismail
# Mahir Sadiq
# Abu kayum sourov
# Tanvir Mahmud
# Nabil Sadique
# Rahi
# Sifwat alvi
# Abdul Munaf
# Akhil Kumar
# Sheikh Sohel Ahmed
# Tabassum Hasan
# Tisum
# Labiba Islam Salsabil
# Tabassum Hasan Tisum
# Reazul Alavhi
# Jarif Islam
# Al-Amin Sany
# Rakib Ahsan
# Akanta Das
# Nahida Marzan
# Tansim Zarin
# Suraya Sultana
# Fariha Binte Reeha
